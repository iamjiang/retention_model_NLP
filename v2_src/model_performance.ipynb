# %%
import os
import numpy as np
import pandas as pd
# from tqdm.auto import tqdm
from tqdm import tqdm
tqdm.pandas(position=0,leave=True)
import random
import argparse
import logging

from sklearn.metrics import roc_auc_score, f1_score,average_precision_score
from sklearn.metrics import precision_recall_fscore_support 
from sklearn.metrics import roc_curve,precision_recall_curve
from sklearn.metrics import auc as auc_score

import textwrap

from datasets import load_dataset, load_metric, concatenate_datasets,DatasetDict,Dataset
from datasets import load_from_disk

import transformers
print("Transformers version is {}".format(transformers.__version__))

import torch

from transformers import (
    AdamW,
    AutoConfig,
    AutoModel,
    AutoModelWithLMHead,
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    AutoModelForSequenceClassification,
    default_data_collator,
    Seq2SeqTrainingArguments,
    Seq2SeqTrainer,
    get_linear_schedule_with_warmup,
    get_scheduler
)

import utils

import seaborn as sns
from pylab import rcParams
from matplotlib import pyplot as plt
from matplotlib import rc

sns.set(style="whitegrid",palette='muted',font_scale=1.2)
# rcParams['figure.figsize']=16,10

# %config InlineBackend.figure_format="retina"
# %matplotlib inline
# Out:
# Transformers version is 4.6.1

# %%
def seed_everything(seed):
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)

# %%
class Sample_Creation:
    def __init__(self, df, subtype, keyword):
        self.df=df
        self.subtype=subtype
        self.keyword=keyword
        
    def subtype_find(self):
        mask=[False for _ in range(len(self.subtype))]
        for i in range(len(self.subtype)):
            for k in self.keyword:
                if k in self.subtype[i]:
                    mask[i]=True
                    break
        return np.array(self.subtype)[mask].tolist()
    
    def data_creation(self,val_ratio, test_ratio, train_pos_neg_ratio, val_pos_neg_ratio, test_pos_neg_ratio):
        """"
        Description
        -----------
        create training, validation and test set for positive and negative samples
    
        Parameters:
        ----------
        val_ratio: validation set ratio, default=10% 
        test_ratio: test set ratio, default=10%.  training set ratio=1-val_ratio-test_ratio
        train_pos_neg_ratio : The proportion of positive sample vs negative sampel in training set
        val_pos_neg_ratio :   The proportion of positive sample vs negative sampel in validation set
        test_pos_neg_ratio :  The proportion of positive sample vs negative sampel in test set

        Returns:
        --------
        Traning, validationa and test dataset including positive and negative samples
        
        """
        _subtype=self.subtype_find()
        pos_sample=self.df[self.df['Subtype'].isin(_subtype)].reset_index()
        neg_sample=self.df[~self.df['Subtype'].isin(_subtype)].reset_index()
        
        def train_val_test(data,val_ratio,test_ratio):
            np.random.seed(101)
            _idx=np.arange(len(data))

            np.random.shuffle(_idx)
            test_idx=_idx[:int(len(_idx)*test_ratio)]
            val_idx=_idx[int(len(_idx)*test_ratio) : int(len(_idx)*(val_ratio+test_ratio))]
            train_idx=_idx[int(len(_idx)*(val_ratio+test_ratio)):]
            
            train_data=data.loc[train_idx,:]
            val_data=data.loc[val_idx,:]
            test_data=data.loc[test_idx,:]
            
            return train_data, val_data, test_data
        
        train_positive, val_positive, test_positive=train_val_test(pos_sample,val_ratio,test_ratio)
        train_negative, val_negative, test_negative=train_val_test(neg_sample,val_ratio,test_ratio)
        
        train_neg_num=len(train_positive)* train_pos_neg_ratio
        val_neg_num=len(val_positive)* val_pos_neg_ratio
        test_neg_num=len(test_positive)* test_pos_neg_ratio
        
        train_negative=train_negative.sample(n=train_neg_num, random_state=101)
        val_negative=val_negative.sample(n=val_neg_num, random_state=101)
        test_negative=test_negative.sample(n=test_neg_num, random_state=101)
        
        train_positive["label"]=1
        val_positive["label"]=1
        test_positive["label"]=1
        
        train_negative["label"]=0
        val_negative["label"]=0
        test_negative["label"]=0
        
        train_df=pd.concat([train_positive, train_negative],axis=0).reset_index()
        val_df=pd.concat([val_positive, val_negative],axis=0).reset_index()
        test_df=pd.concat([test_positive, test_negative],axis=0).reset_index()
        
        # train_df.to_csv(os.path.join(args.output_dir ,'train_df.csv'))
        # val_df.to_csv(os.path.join(args.output_dir ,'val_df.csv'))
        # test_df.to_csv(os.path.join(args.output_dir ,'test_df.csv'))
        return train_df, val_df, test_df

# %%
input_dir="s3://trident-retention-output/"
askunum_text=pd.read_pickle(os.path.join(input_dir,"askunum_text"))
askunum_text['Subtype'] = askunum_text['Subtype'].fillna("").astype(str).str.lower()
askunum_text["Subtype"]=askunum_text["Subtype"].progress_apply(lambda x: x.encode("latin1").decode("cp1252"))
askunum_text["Subtype"]=askunum_text["Subtype"].str.replace("/"," or ")
askunum_text["Subtype"]=askunum_text["Subtype"].str.replace("&"," and ")
askunum_text["Subtype"]=askunum_text["Subtype"].str.replace(r"\s{2,}", " ", regex=True)
    
df=askunum_text[~askunum_text["Subtype"].isin(["attempted self-service - billing support"])]
subtype=list(df["Subtype"].unique())
keyword=["bill not received","bill hold","bill hide or delete"]
sample_class=Sample_Creation(df, subtype, keyword)
train_df, val_df, test_df=sample_class.data_creation(val_ratio=0.1, test_ratio=0.1, train_pos_neg_ratio=3, val_pos_neg_ratio=3, test_pos_neg_ratio=9)
# Out:
# 100%|██████████| 1452978/1452978 [00:02<00:00, 656246.60it/s]

# %%
def label_distribution(df):
    tempt1=pd.DataFrame(df["label"].value_counts(dropna=False)).reset_index().rename(columns={'index':'label','label':'count'})
    tempt2=pd.DataFrame(df["label"].value_counts(dropna=False,normalize=True)).reset_index().rename(columns={'index':'label','label':'percentage'})
    return tempt1.merge(tempt2, on="label", how="inner")

def style_format(df,  data_type="Training set"):
    return df.style.format({'count':'{:,}','percentage':'{:.2%}'})\
           .set_caption(f"{data_type} label distribution")\
           .set_table_styles([{'selector': 'caption','props': [('color', 'red'),('font-size', '12px')]}])

# %%
label_train=label_distribution(train_df)
style_format(label_train,  data_type="Training set")
# Out:
# <style type="text/css">
# #T_c9f5e_ caption {
#   color: red;
#   font-size: 12px;
# }
# </style>
# <table id="T_c9f5e_">
#   <caption>Training set label distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9f5e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c9f5e_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_c9f5e_row0_col1" class="data row0 col1" >14,316</td>
#       <td id="T_c9f5e_row0_col2" class="data row0 col2" >75.00%</td>
#     </tr>
#     <tr>
#       <th id="T_c9f5e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c9f5e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_c9f5e_row1_col1" class="data row1 col1" >4,772</td>
#       <td id="T_c9f5e_row1_col2" class="data row1 col2" >25.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
label_train=label_distribution(val_df)
style_format(label_train,  data_type="validation set")
# Out:
# <style type="text/css">
# #T_06c8c_ caption {
#   color: red;
#   font-size: 12px;
# }
# </style>
# <table id="T_06c8c_">
#   <caption>validation set label distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06c8c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_06c8c_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_06c8c_row0_col1" class="data row0 col1" >1,791</td>
#       <td id="T_06c8c_row0_col2" class="data row0 col2" >75.00%</td>
#     </tr>
#     <tr>
#       <th id="T_06c8c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_06c8c_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_06c8c_row1_col1" class="data row1 col1" >597</td>
#       <td id="T_06c8c_row1_col2" class="data row1 col2" >25.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
label_train=label_distribution(test_df)
style_format(label_train,  data_type="Test set")
# Out:
# <style type="text/css">
# #T_3b6a8_ caption {
#   color: red;
#   font-size: 12px;
# }
# </style>
# <table id="T_3b6a8_">
#   <caption>Test set label distribution</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >label</th>
#       <th class="col_heading level0 col1" >count</th>
#       <th class="col_heading level0 col2" >percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b6a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b6a8_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_3b6a8_row0_col1" class="data row0 col1" >5,364</td>
#       <td id="T_3b6a8_row0_col2" class="data row0 col2" >90.00%</td>
#     </tr>
#     <tr>
#       <th id="T_3b6a8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b6a8_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_3b6a8_row1_col1" class="data row1 col1" >596</td>
#       <td id="T_3b6a8_row1_col2" class="data row1 col2" >10.00%</td>
#     </tr>
#   </tbody>
# </table>

# %%
wrapper = textwrap.TextWrapper(width=150) 
# Randomly choose some examples.
for i in range(5):
    random.seed(101+i)
    
    j = random.choice(train_df.index)
    emails=train_df.loc[j,"TextBody"]
    subtype=train_df.loc[j,"Subtype"]
    unum_id=train_df.loc[j,"unum_id"]
    
    print('')
    print("*"*80)
    print(f'*  Full TextBody : unum_id={unum_id}, subtype={subtype} *')
    print("*"*80)
    print('')
    # print(j)
    print(wrapper.fill(emails))
    print('')
    print("*"*50)
# Out:
# ********************************************************************************
# *  Full TextBody : unum_id=660146, subtype=eoi status *
# ********************************************************************************
#
# hi team, please see attached and below regarding eois fothe mote marine enrollment fo/1. i am unfamiliawith the unum inbox they sent this to, so i
# want to ensuwe ataking action steps as needed. can you partnewith client services foresolution and follow up with the brokethank you, catherine thorpe
# unum client manageflorida o 813.207.2637 c 813.734.4393 foinformation and resources regarding unum's covid-19 response and faqs, visit hello natalie,
# . i have confirmed that the effective dates fothese employees have been updated to 5/1/2021 as requested. if we may assist any furtheplease let us
# know. thank you, amanda altieservice specialist client success organization 1-800-ask-unum 1-800-275-8686 askunumunum.com unum covid-19 response - how
# to file a claim online - . , .
#
# **************************************************
#
# ********************************************************************************
# *  Full TextBody : unum_id=193506127, subtype=charge or credit clarification *
# ********************************************************************************
#
# attention seattle hi team, i hope all is well. plan admin, mary kay bennett, 509 624-1308 ohas called regarding the most recent payment applied to
# theijune bill. she has reviewed all payment sent to us and confirmed they have not sent anything fojune. they pay via ach and the following is what
# they have sent. jan 2 $373.60 feb 1 $373.60 ma. $373.60 april 1 $259.94 april 25 $359.58 these all line up and they have not yet paid fojune. based on
# review thewas $633.00 applied to theijune bill, leaving a $273.42 credit. this was not from them. please review to determine why this money was
# applied to this account and update accordingly. thank you, jo-ann douglass service specialist unum client service cente-800-ask-unum 1-800-275-8686
#
# **************************************************
#
# ********************************************************************************
# *  Full TextBody : unum_id=357787842, subtype=enrollment status *
# ********************************************************************************
#
# hello askunum, best western plus hilltop inn - unum 410751 i am following up on the below email submitted by my associate, vanessa de la torback in
# july. vanessa is currently out of the office on a leave and the employehas just reached out today 9/11/18 advising this person is still not on the
# most recent invoice. we need to get the unum app processed and coverage issued fothis membeas they weto have been covered effective, 5/1/18. please
# review and advise back - thank you, kelley hoag account manageinterwest insurance services, llc 1357 chico, ca 95973 530 715-2747 office 800 873-3725
# toll free 530 715-2797 fax ca lic 0b01094 khoagiwins.com to betteserve you, interwest is migrating to a new state-of-the-art client management system
# effective august 20th, 2018. as a result, invoices and othedocuments you receive from us will have a new look. we adoing all in oupoweto make this a
# seamless transition fooupartners while improving the quality of the service we provide. let ouexperience guide you. the services provided, as
# contemplated undethis agreement, do not include the provision of legal advice. inc. is not authorized to practice law oprovide legal advice. to the
# extent guidance is provided by interwest, it is not intended, and should not be viewed, as legal advice. nois the provision of any such services to be
# considered obe deemed to be in any way made available as an inducement to establish omaintain a business relationship with interwest. you should
# consult with youown legal counsel folegal advice and should confirm with that counsel that any guidance provided by interwest meets all applicable
# legal requirements. you will indemnify and hold harmless interwest foclaims of any type arising from guidance provided by interwest. this message
# contains confidential information and is intended only fothe individual named. if you anot the named addressee you should not disseminate, distribute
# ocopy this e-mail. please notify the sendeimmediately by e-mail if you have received this e-mail by mistake and delete this e-mail from yousystem.
# e-mail transmission cannot be guaranteed to be secuoerror-free as information could be intercepted, corrupted, lost, destroyed, arrive late
# oincomplete, ocontain viruses. the sendetherefodoes not accept liability foany errors oomissions in the contents of this message, which arise as a
# result of e-mail transmission. if verification is required please request a hard-copy version. interwest insurance services, llc, 1357 e. lassen ave.
# chico, ca 95973 ----- ----- hi kelly, thank you focontacting unum. i hope youday is going well. luana gutierrez had priocoverage with unum, effective
# 10/1/2015. the coverage terminated effective 11/1/2017. ms. gutierrez was enrolled on line by erin martinez as a new hiand should have been enrolled
# as a rehire. i have reinstated the coverage foms. gutierrez with an effective date 5/1/2018. the rehiwill be reflected on the 11/1/2018. the total
# premium due will be $12.08. moving forward the monthly premium will be $1.80. please let us know if you have any questions oif theis anything else we
# can assist you with. thank you, yvette knowlton service specialist unum client service cente-800-ask-unum 1-800-275-8686 hi yvette, thank you very
# much foyouassistance on getting this corrected fothe group. i will shathis with the employer. hi yvette, i advised the client, who was appreciative of
# unum correcting this so quickly. howevethey did have the following feedback. can you review and advise from unum's perspective? peclient - the hadmin
# is not always awawhen the enrollment is a new hiorehire. is thea reason unum requires the different enrollment? is theanyway to change this fothem? -
# why was this pended foso long as it was an online enrollment with no communication eitheto the client ointerwest vanessa de la torwould have been
# account manage hi yvette, i advised the client, who was appreciative of unum correcting this so quickly. howevethey did have the following feedback.
# can you review and advise from unum's perspective? peclient - the hadmin is not always awawhen the enrollment is a new hiorehire. is thea reason unum
# requires the different enrollment? is theanyway to change this fothem? - why was this pended foso long as it was an online enrollment with no
# communication eitheto the client ointerwest vanessa de la torwould have been account manage hi kelley, thank you fothe response. we need to know if
# its a rehionew hisince a rehiwould already be in ousystem and ouonline system will not let the employeadd an employee with the same ssn. if the
# employeadds a rehias a new hithey will be unable to as we already have the employee in ousystem. if the employee is not fully enrolled correctly then
# ousystem will not detect any change, thus not notifying anyone. since luana gutierrez was enrolled incorrectly no one was notified of the change. i
# hope this information is helpful and . have a wonderful day thank you, cameron ray service specialist unum client service cente-800-ask-unum
# 1-800-275-8686 hi cameron, thank you foproviding furtheclarification on the inquiry below. regarding the erroon the enrollment - so is the only way
# fothe client to confirm membewas enrolled correctly is to review/monitotheibilling once they process a membeonline? i would like to be able to provide
# the client with some guidance as to how to avoid this in the future. hi cameron, thank you foproviding furtheclarification on the inquiry below.
# regarding the erroon the enrollment - so is the only way fothe client to confirm membewas enrolled correctly is to review/monitotheibilling once they
# process a membeonline? i would like to be able to provide the client with some guidance as to how to avoid this in the future. hello kelley, . to
# ensuthat employees aenrolled correctly clients can monitotheibilling, request a census listing of inforce employees ocontact ask unum to confirm the
# enrollment details. please let us know if you have questions oneed furtheinformation that we can assist you with. thank you, jamie ewing service
# specialist unum client service cente-800-ask-unum 1-800-275-8686 askunumunum.com . , . --------------- hi jamie, thank you fothe reply below. i will
# advise the group.
#
# **************************************************
#
# ********************************************************************************
# *  Full TextBody : unum_id=735965, subtype=bill not received *
# ********************************************************************************
#
# good afternoon coral, it was a pleasuspeaking with you today. attached is a copy of the 9/1/2018 invoice fothe word of god. please let us know if
# theis anything else that we could assist you with. thank you, maryjo schmidt service specialist unum client service cente-800-ask-unum 1-800-275-8686
# would you please send me an invoice fojanuary 2019? i found out we would still be needing one, but we didn???t receive one in the mail.?? i believe
# because we had initially thought we would be terminating coverage. ?? fonow, i have whited-out last month???s copy and wrote the new figures in the
# form.?? if i need to, i can just send you that fothis month fojanuary 2019 coverage. ?? thank you foyouhelp. ?? coral lee the word of god policy
# 0388609 div 001??
#
# **************************************************
#
# ********************************************************************************
# *  Full TextBody : unum_id=361876718, subtype=add, remove, or update user access *
# ********************************************************************************
#
# i'm trying to set up online access to file a claim. below is the information that has been requested employeregistration getting setup to
# administeyouplans online is a simple process to get started just call oemail us with this basic information. company name bastrop isd plan
# administratoname marsha goertz phone numbeand email address 512-772-7135 policy numbers 628649 please let me know if you need any additional
# information. marsha goertz leave benefits managebastrop isd 906 farm st. bastrop, tx 78602 512/772-7135 ph 512/308-9501 fax we do not have to agree on
# anything to be kind to one another. hi marsha, . i have added online access foyou. you will receive an email with temporary password and login
# instructions. we would be happy to have an orientation done to review the policy details and website navigation. please let us know if you have any
# questions. thank you, laura m fargo service specialist ask unum - service operations 1-800-ask-unum 1-800-275-8686 , 8am to 8pm time.
#
# **************************************************

# %%
def metric_table(table_name="training_output.txt"):
    Model_Type=[]
    EPOCH=[]
    LOSS=[]
    True_Prediction=[]
    False_Prediction=[]
    Accuracy=[]
    Precision=[]
    Recall=[]
    F1_Score=[]
    AUC=[]
    PR_AUC=[]

    with open(os.path.join(os.getcwd(),table_name),'r') as f:
        for line in f:
            Model_Type.append(str(line.split(",")[0]))
            EPOCH.append(int(line.split(",")[1]))
            LOSS.append(float(line.split(",")[2]))
            True_Prediction.append(int(line.split(",")[3]))
            False_Prediction.append(int(line.split(",")[4]))
            Accuracy.append(float(line.split(",")[5]))
            Precision.append(float(line.split(",")[6]))
            Recall.append(float(line.split(",")[7]))
            F1_Score.append(float(line.split(",")[8]))
            AUC.append(float(line.split(",")[12]))
            PR_AUC.append(float(line.split(",")[13]))

    metrics=pd.DataFrame({"model_type":Model_Type,"epoch":EPOCH,"loss":LOSS,"true_prediction":True_Prediction,"false_prediction":False_Prediction,"accuracy":Accuracy,\
                         "precision":Precision,"recall":Recall,"f1_score":F1_Score,"auc":AUC,"pr_auc":PR_AUC})
    metrics.drop_duplicates(subset=["model_type","epoch"],inplace=True)
    metrics.sort_values(by=['model_type','epoch'],inplace=True)       
    
    return metrics

def style_format(metrics_training, metrics_test, model):
    metrics_training=metrics_training[metrics_training["model_type"]==model].reset_index(drop=True)
    metrics_training=metrics_training.sort_values('f1_score', ascending=False).head(1)
    metrics_training.drop("epoch",inplace=True,axis=1)
    metrics_training["data"]=["training set"]
    
    metrics_test=metrics_test[metrics_test["model_type"]==model].reset_index(drop=True)
    metrics_test=metrics_test.sort_values('f1_score', ascending=False).head(1)
    metrics_test.drop("epoch",inplace=True,axis=1)
    metrics_test["data"]=["test set"]
    
    metrics=pd.concat([metrics_training,metrics_test])
    first_column =  metrics.pop('data')
    metrics.insert(0, 'data', first_column)
    
    return metrics.style.format({"loss":"{:.4f}","accuracy":"{:.2%}","true_prediction":"{:,}","false_prediction":"{:,}", "precision":"{:.2%}", "recall":"{:.2%}", \
                                "f1_score":"{:.2%}", "auc":"{:.2%}","pr_auc":"{:.2%}"}) \
    .set_caption(f"Performance Summary for-- {model}") \
    .set_table_styles([{
        'selector': 'caption',
        'props': [
            ('color', 'red'),
            ('font-size', '20px')
        ]
    }])

# %%
metric_training=metric_table(table_name="metrics_training.txt")
metric_test=metric_table(table_name="metrics_test.txt")

# %%
style_format(metric_training,metric_test, model="bert_base")
# Out:
# <style type="text/css">
# #T_062a8_ caption {
#   color: red;
#   font-size: 20px;
# }
# </style>
# <table id="T_062a8_">
#   <caption>Performance Summary for-- bert_base</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data</th>
#       <th class="col_heading level0 col1" >model_type</th>
#       <th class="col_heading level0 col2" >loss</th>
#       <th class="col_heading level0 col3" >true_prediction</th>
#       <th class="col_heading level0 col4" >false_prediction</th>
#       <th class="col_heading level0 col5" >accuracy</th>
#       <th class="col_heading level0 col6" >precision</th>
#       <th class="col_heading level0 col7" >recall</th>
#       <th class="col_heading level0 col8" >f1_score</th>
#       <th class="col_heading level0 col9" >auc</th>
#       <th class="col_heading level0 col10" >pr_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_062a8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_062a8_row0_col0" class="data row0 col0" >training set</td>
#       <td id="T_062a8_row0_col1" class="data row0 col1" >bert_base</td>
#       <td id="T_062a8_row0_col2" class="data row0 col2" >0.6106</td>
#       <td id="T_062a8_row0_col3" class="data row0 col3" >13,766</td>
#       <td id="T_062a8_row0_col4" class="data row0 col4" >7,710</td>
#       <td id="T_062a8_row0_col5" class="data row0 col5" >64.10%</td>
#       <td id="T_062a8_row0_col6" class="data row0 col6" >41.59%</td>
#       <td id="T_062a8_row0_col7" class="data row0 col7" >69.38%</td>
#       <td id="T_062a8_row0_col8" class="data row0 col8" >52.01%</td>
#       <td id="T_062a8_row0_col9" class="data row0 col9" >74.41%</td>
#       <td id="T_062a8_row0_col10" class="data row0 col10" >49.50%</td>
#     </tr>
#     <tr>
#       <th id="T_062a8_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_062a8_row1_col0" class="data row1 col0" >test set</td>
#       <td id="T_062a8_row1_col1" class="data row1 col1" >bert_base</td>
#       <td id="T_062a8_row1_col2" class="data row1 col2" >0.6145</td>
#       <td id="T_062a8_row1_col3" class="data row1 col3" >3,632</td>
#       <td id="T_062a8_row1_col4" class="data row1 col4" >2,328</td>
#       <td id="T_062a8_row1_col5" class="data row1 col5" >60.94%</td>
#       <td id="T_062a8_row1_col6" class="data row1 col6" >20.06%</td>
#       <td id="T_062a8_row1_col7" class="data row1 col7" >56.54%</td>
#       <td id="T_062a8_row1_col8" class="data row1 col8" >29.61%</td>
#       <td id="T_062a8_row1_col9" class="data row1 col9" >72.28%</td>
#       <td id="T_062a8_row1_col10" class="data row1 col10" >24.58%</td>
#     </tr>
#   </tbody>
# </table>

# %%
style_format(metric_training,metric_test, model="bert_large")
# Out:
# <style type="text/css">
# #T_be2a9_ caption {
#   color: red;
#   font-size: 20px;
# }
# </style>
# <table id="T_be2a9_">
#   <caption>Performance Summary for-- bert_large</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data</th>
#       <th class="col_heading level0 col1" >model_type</th>
#       <th class="col_heading level0 col2" >loss</th>
#       <th class="col_heading level0 col3" >true_prediction</th>
#       <th class="col_heading level0 col4" >false_prediction</th>
#       <th class="col_heading level0 col5" >accuracy</th>
#       <th class="col_heading level0 col6" >precision</th>
#       <th class="col_heading level0 col7" >recall</th>
#       <th class="col_heading level0 col8" >f1_score</th>
#       <th class="col_heading level0 col9" >auc</th>
#       <th class="col_heading level0 col10" >pr_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_be2a9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_be2a9_row0_col0" class="data row0 col0" >training set</td>
#       <td id="T_be2a9_row0_col1" class="data row0 col1" >bert_large</td>
#       <td id="T_be2a9_row0_col2" class="data row0 col2" >0.3085</td>
#       <td id="T_be2a9_row0_col3" class="data row0 col3" >18,912</td>
#       <td id="T_be2a9_row0_col4" class="data row0 col4" >2,564</td>
#       <td id="T_be2a9_row0_col5" class="data row0 col5" >88.06%</td>
#       <td id="T_be2a9_row0_col6" class="data row0 col6" >80.91%</td>
#       <td id="T_be2a9_row0_col7" class="data row0 col7" >83.89%</td>
#       <td id="T_be2a9_row0_col8" class="data row0 col8" >82.37%</td>
#       <td id="T_be2a9_row0_col9" class="data row0 col9" >95.06%</td>
#       <td id="T_be2a9_row0_col10" class="data row0 col10" >83.82%</td>
#     </tr>
#     <tr>
#       <th id="T_be2a9_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_be2a9_row1_col0" class="data row1 col0" >test set</td>
#       <td id="T_be2a9_row1_col1" class="data row1 col1" >bert_large</td>
#       <td id="T_be2a9_row1_col2" class="data row1 col2" >0.2766</td>
#       <td id="T_be2a9_row1_col3" class="data row1 col3" >5,146</td>
#       <td id="T_be2a9_row1_col4" class="data row1 col4" >814</td>
#       <td id="T_be2a9_row1_col5" class="data row1 col5" >86.34%</td>
#       <td id="T_be2a9_row1_col6" class="data row1 col6" >62.68%</td>
#       <td id="T_be2a9_row1_col7" class="data row1 col7" >81.71%</td>
#       <td id="T_be2a9_row1_col8" class="data row1 col8" >70.94%</td>
#       <td id="T_be2a9_row1_col9" class="data row1 col9" >95.56%</td>
#       <td id="T_be2a9_row1_col10" class="data row1 col10" >67.79%</td>
#     </tr>
#   </tbody>
# </table>

# %%
style_format(metric_training,metric_test, model="roberta_base")
# Out:
# <style type="text/css">
# #T_38a8a_ caption {
#   color: red;
#   font-size: 20px;
# }
# </style>
# <table id="T_38a8a_">
#   <caption>Performance Summary for-- roberta_base</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data</th>
#       <th class="col_heading level0 col1" >model_type</th>
#       <th class="col_heading level0 col2" >loss</th>
#       <th class="col_heading level0 col3" >true_prediction</th>
#       <th class="col_heading level0 col4" >false_prediction</th>
#       <th class="col_heading level0 col5" >accuracy</th>
#       <th class="col_heading level0 col6" >precision</th>
#       <th class="col_heading level0 col7" >recall</th>
#       <th class="col_heading level0 col8" >f1_score</th>
#       <th class="col_heading level0 col9" >auc</th>
#       <th class="col_heading level0 col10" >pr_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38a8a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_38a8a_row0_col0" class="data row0 col0" >training set</td>
#       <td id="T_38a8a_row0_col1" class="data row0 col1" >roberta_base</td>
#       <td id="T_38a8a_row0_col2" class="data row0 col2" >0.2295</td>
#       <td id="T_38a8a_row0_col3" class="data row0 col3" >19,281</td>
#       <td id="T_38a8a_row0_col4" class="data row0 col4" >2,195</td>
#       <td id="T_38a8a_row0_col5" class="data row0 col5" >89.78%</td>
#       <td id="T_38a8a_row0_col6" class="data row0 col6" >84.42%</td>
#       <td id="T_38a8a_row0_col7" class="data row0 col7" >86.20%</td>
#       <td id="T_38a8a_row0_col8" class="data row0 col8" >85.30%</td>
#       <td id="T_38a8a_row0_col9" class="data row0 col9" >96.99%</td>
#       <td id="T_38a8a_row0_col10" class="data row0 col10" >92.88%</td>
#     </tr>
#     <tr>
#       <th id="T_38a8a_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_38a8a_row1_col0" class="data row1 col0" >test set</td>
#       <td id="T_38a8a_row1_col1" class="data row1 col1" >roberta_base</td>
#       <td id="T_38a8a_row1_col2" class="data row1 col2" >0.2763</td>
#       <td id="T_38a8a_row1_col3" class="data row1 col3" >5,277</td>
#       <td id="T_38a8a_row1_col4" class="data row1 col4" >683</td>
#       <td id="T_38a8a_row1_col5" class="data row1 col5" >88.54%</td>
#       <td id="T_38a8a_row1_col6" class="data row1 col6" >75.98%</td>
#       <td id="T_38a8a_row1_col7" class="data row1 col7" >78.02%</td>
#       <td id="T_38a8a_row1_col8" class="data row1 col8" >76.99%</td>
#       <td id="T_38a8a_row1_col9" class="data row1 col9" >97.37%</td>
#       <td id="T_38a8a_row1_col10" class="data row1 col10" >84.90%</td>
#     </tr>
#   </tbody>
# </table>

# %%
style_format(metric_training,metric_test, model="roberta_large")
# Out:
# <style type="text/css">
# #T_0041f_ caption {
#   color: red;
#   font-size: 20px;
# }
# </style>
# <table id="T_0041f_">
#   <caption>Performance Summary for-- roberta_large</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >data</th>
#       <th class="col_heading level0 col1" >model_type</th>
#       <th class="col_heading level0 col2" >loss</th>
#       <th class="col_heading level0 col3" >true_prediction</th>
#       <th class="col_heading level0 col4" >false_prediction</th>
#       <th class="col_heading level0 col5" >accuracy</th>
#       <th class="col_heading level0 col6" >precision</th>
#       <th class="col_heading level0 col7" >recall</th>
#       <th class="col_heading level0 col8" >f1_score</th>
#       <th class="col_heading level0 col9" >auc</th>
#       <th class="col_heading level0 col10" >pr_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0041f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0041f_row0_col0" class="data row0 col0" >training set</td>
#       <td id="T_0041f_row0_col1" class="data row0 col1" >roberta_large</td>
#       <td id="T_0041f_row0_col2" class="data row0 col2" >0.1680</td>
#       <td id="T_0041f_row0_col3" class="data row0 col3" >19,923</td>
#       <td id="T_0041f_row0_col4" class="data row0 col4" >1,553</td>
#       <td id="T_0041f_row0_col5" class="data row0 col5" >92.77%</td>
#       <td id="T_0041f_row0_col6" class="data row0 col6" >91.65%</td>
#       <td id="T_0041f_row0_col7" class="data row0 col7" >87.50%</td>
#       <td id="T_0041f_row0_col8" class="data row0 col8" >89.53%</td>
#       <td id="T_0041f_row0_col9" class="data row0 col9" >98.34%</td>
#       <td id="T_0041f_row0_col10" class="data row0 col10" >96.18%</td>
#     </tr>
#     <tr>
#       <th id="T_0041f_level0_row1" class="row_heading level0 row1" >0</th>
#       <td id="T_0041f_row1_col0" class="data row1 col0" >test set</td>
#       <td id="T_0041f_row1_col1" class="data row1 col1" >roberta_large</td>
#       <td id="T_0041f_row1_col2" class="data row1 col2" >0.1948</td>
#       <td id="T_0041f_row1_col3" class="data row1 col3" >5,481</td>
#       <td id="T_0041f_row1_col4" class="data row1 col4" >479</td>
#       <td id="T_0041f_row1_col5" class="data row1 col5" >91.96%</td>
#       <td id="T_0041f_row1_col6" class="data row1 col6" >88.77%</td>
#       <td id="T_0041f_row1_col7" class="data row1 col7" >80.87%</td>
#       <td id="T_0041f_row1_col8" class="data row1 col8" >84.64%</td>
#       <td id="T_0041f_row1_col9" class="data row1 col9" >98.68%</td>
#       <td id="T_0041f_row1_col10" class="data row1 col10" >92.01%</td>
#     </tr>
#   </tbody>
# </table>
