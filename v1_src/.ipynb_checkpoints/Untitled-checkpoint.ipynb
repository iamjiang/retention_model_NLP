# %%
import argparse
import time
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('words')
from nltk.tokenize import word_tokenize
from functools import reduce
en_stopwords = set(stopwords.words('english')) 
import itertools
import re
import os
import pickle

import datasets
from datasets import load_dataset, load_metric, Dataset, concatenate_datasets
from datasets import load_from_disk
from tqdm import tqdm
tqdm.pandas(position=0,leave=True)

import textwrap
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /home/ec2-user/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to /home/ec2-user/nltk_data...
# [nltk_data]   Package words is already up-to-date!

# %%
argparser = argparse.ArgumentParser("Data Preprocessing") 
argparser.add_argument('--year', type=str, default="unique_unum_v1")
args,_ = argparser.parse_known_args()

print(args)

my_folder="s3://trident-retention-output/"
folder = 's3://trident-retention-data/askunum/'
# Out:
# Namespace(year='unique_unum_v1')

# %%
def load_askunum_df(folder, year, usecols=None, nrows=None): 
    if year == 2018: # ['ID', 'PARENTID', 'PARENT.CREATEDDATE', 'PARENT.CLOSEDDATE']
        askunum_df = pd.read_csv(folder + 'askunum_2018.csv', encoding='latin-1', usecols=usecols, nrows=nrows)
       
    if year == 2019: 
        askunum_df = pd.concat([pd.read_csv(folder + 'askunum_2019_{}.csv'.format(i), encoding='latin-1', usecols=usecols, nrows=nrows) for i in range(1, 4)]) 
        
    if year == 2020:  
        askunum_df = pd.concat([pd.read_csv(folder + 'unnested_2020_{}_customer.csv'.format(i), encoding='latin-1', usecols=usecols, nrows=nrows) for i in range(10)])

    if year == 2021: 
        askunum_df = pd.concat([pd.read_csv(folder + 'unnested_2021_{}_customer.csv'.format(i), encoding='latin-1', usecols=usecols, nrows=nrows) for i in range(10)]) 
        
    if year == 2022: 
        askunum_df = pd.concat([pd.read_csv(folder + 'askunum_2022_{}.csv'.format(i), encoding='latin-1', usecols=usecols, nrows=nrows) for i in range(0, 4)])
        
    return askunum_df

# %%
args.year=2022
year=args.year

# %%
if year in [2018, 2019]: 
    idx = 'ID'
    parent_id = 'PARENTID'
    text_body = 'TEXTBODY'
    created_date = 'PARENT.CREATEDDATE'
    closed_date = 'PARENT.CLOSEDDATE'
    Incoming='INCOMING'
    subtype= 'PARENT.SUB_TYPE_TXT__C' 
    message_date= 'MESSAGEDATE'

if year in [2020, 2021]: 
    idx = 'Id'
    parent_id = 'ParentId'
    text_body = 'TextBody'
    created_date = 'CreatedDate' 
    closed_date = 'ClosedDate'
    Incoming='Incoming'
    subtype= 'SUB_TYPE_TXT__c'
    message_date= 'MessageDate'

if year in [2022]:
    idx = 'Id'
    parent_id = 'ParentId'
    text_body = 'TextBody'
    created_date = 'Parent.CreatedDate'  
    closed_date = 'Parent.ClosedDate'
    Incoming='Incoming'
    subtype= 'Parent.SUB_TYPE_TXT__c'
    message_date= 'MessageDate'

askunum_text = load_askunum_df(folder, year, usecols = [idx, parent_id, text_body, created_date, closed_date, Incoming, subtype,message_date], nrows=5)

# %%
askunum_text.head(2)

# %%
df=pd.DataFrame({"id":[1,2],"text":["Hello, word. I am chadadf ok nice.","It is a nice adafred day. ok nice, I know dfadad. nice."]})
df

# %%
## removing non-english words from text
words = set(nltk.corpus.words.words())
df['text'] = df['text'].apply(lambda x: " ".join(w for w in nltk.wordpunct_tokenize(x) if w.lower() in words or not w.isalpha()))

# %%
df

# %%
my_folder="s3://trident-retention-output/"
file_name="unique_unum_v1"
unique_unum_id=pd.read_csv(os.path.join(my_folder,file_name+".csv"))
unique_unum_id.head()

# %%
year=2022
my_folder="s3://trident-retention-output/"
df=pd.read_csv(os.path.join(my_folder,f"askunum_textbody_{year}"+".csv"))
df.head(2)

# %%
askunum_text=pd.DataFrame()
for year in [2018,2019,2020,2021,2022]:
    new_data=pd.read_csv(os.path.join(my_folder,f"askunum_textbody_{year}"+".csv"))
    askunum_text=pd.concat([askunum_text,new_data])
    # print(askunum_text.shape)
    print(f"{:<25}{:<25,}".format(year,new_data.shape[0]))
# Out:
# (1023585, 13)
# (2173519, 13)
# (3348090, 13)
# (4493050, 13)
# (5016545, 13)

# %%
print("{:<15}{:<20,}".format(year,new_data.shape[0]))
# Out:
# 2022           523,495

# %%
askunum_text.head(2)
# Out:
#    Unnamed: 0                  Id            ParentId  Incoming  \
# 0           0  02s0c00001KQIDDAA5  5000c00001iYULlAAO      True
# 1           1  02s0c00001KQg0hAAD  5000c00001iYULlAAO     False
#
#                 MessageDate  \
# 0  2018-12-27T17:51:02.000Z
# 1  2018-12-28T19:16:56.000Z
#
#                                             TextBody  \
# 0  please see attached, the form showing that cry...
# 1  good afternoon robin, thank you for contacting...
#
#                  CreatedDate                ClosedDate                Subtype  \
# 0  2018-12-27 17:51:24+00:00  2018-12-28T19:18:23.000Z  Enrollment Submission
# 1  2018-12-27 17:51:24+00:00  2018-12-28T19:18:23.000Z  Enrollment Submission
#
#    year  month       account_id      unum_id
# 0  2018     12  001a000001lKDBx  440668861.0
# 1  2018     12  001a000001lKDBx  440668861.0

# %%
askunum_text.drop(['Unnamed: 0'],axis=1,inplace=True)
askunum_text['unum_id']=askunum_text['unum_id'].astype(int).astype(str)
askunum_text.sort_values(["unum_id","year","month","MessageDate"],inplace=True,ascending=True)
askunum_text.to_pickle(os.path.join(my_folder,"askunum_text_pickle"))

# %%
start=time.time()
askunum_text=pd.read_pickle(os.path.join(my_folder,'askunum_text_pickle'))
end=time.time()
print("It took {:0.4f} seconds to read text data".format(end-start))
# Out:
# It took 233.3024 seconds to read text data

# %%
askunum_text.shape
# Out:
# (5016545, 12)

# %%
askunum_text.head(2)
# Out:
#                          Id            ParentId  Incoming  \
# 1136587  02s3x00001lwyxeAAA  5003x00002CFUfAAAX     False
# 1136585  02s3x00001lwzYbAAI  5003x00002CFUfAAAX     False
#
#                           MessageDate  \
# 1136587  2021-10-25T17:07:44.000+0000
# 1136585  2021-10-25T17:08:22.000+0000
#
#                                                   TextBody  \
# 1136587  fopittsburgh pa pam schon emailpambloomfieldga...
# 1136585  hi pam, i hope this email finds you well. we a...
#
#                        CreatedDate                    ClosedDate  \
# 1136587  2021-10-22 17:18:20+00:00  2021-10-25T17:08:45.000+0000
# 1136585  2021-10-22 17:18:20+00:00  2021-10-25T17:08:45.000+0000
#
#                                 Subtype  year  month       account_id  \
# 1136587  Charge or Credit Clarification  2021     10  0013x00002Ipz9G
# 1136585  Charge or Credit Clarification  2021     10  0013x00002Ipz9G
#
#             unum_id
# 1136587  1000110382
# 1136585  1000110382

# %%
np.unique(askunum_text["Subtype"].apply(str).values).shape
# Out:
# (156,)

# %%
unum_id=np.unique(tempt.unum_id.values)
unum_id
# Out:
# array(['1029314', '1032773472', '1106085736', '203278756', '218081500',
#        '250346112', '521502', '667906663', '711161932', '797598268',
#        '870566381', '879092819'], dtype=object)

# %%
np.array_split(unum_id,5)
# Out:
# [array(['1029314', '1032773472', '1106085736'], dtype=object),
#  array(['203278756', '218081500', '250346112'], dtype=object),
#  array(['521502', '667906663'], dtype=object),
#  array(['711161932', '797598268'], dtype=object),
#  array(['870566381', '879092819'], dtype=object)]

# %%
df=pd.read_csv(os.path.join(my_folder, "unique_unum_v1.csv"))["0"].values
df
# Out:
# array([1000110382, 1000210715, 1000233839, ...,  167994141,  167996771,
#         168007991])

# %%
def chunks_split(data,n):
    k=len(data)//n
    for i in range(0,n-1):
        yield data[i*k:(i+1)*k]
    yield data[(n-1)*k:]
    
unum_id=np.unique(askunum_text.unum_id.values)
chunk=chunks_split(unum_id,10)

# %%
unum_id
# Out:
# array(['1000110382', '1000197507', '1000210715', ..., '999535665',
#        '999536230', '999603547'], dtype=object)

# %%
for i in tqdm(range(4)):
    print(next(iter(chunk)))
# Out:
# 100%|██████████| 4/4 [00:00<00:00, 10407.70it/s]
# ['1000110382' '1000197507' '1000210715' ... '162089611' '162095022'
#  '162100821']
# ['162115948' '162121782' '162125981' ... '346666687' '346669776'
#  '346688639']
# ['346715331' '346718562' '34674078' ... '463385' '463388' '463399']
# ['463401029' '463402159' '46343729' ... '526434' '526444' '526454']

# %%
tempt=next(iter(chunk))

# %%
pd.DataFrame(tempt,columns=["unum_id"]).reset_index(drop=True).to_csv("tempt.csv")

# %%
pd.read_csv("tempt.csv",usecols=["unum_id"]).head()
# Out:
#      unum_id
# 0     590992
# 1  590996294
# 2     590998
# 3     590999
# 4     591023

# %%
next(iter(chunk))
# Out:
# array(['502232', '507668553', '558933586'], dtype=object)

# %%
next(iter(chunk))
# Out:
# array(['564543503', '625762', '650410023'], dtype=object)

# %%
next(iter(chunk))
# Out:
# array(['715351897', '743568709', '743807465', '842965', '994377397'],
#       dtype=object)

# %%
askunum_text.head(2)
# Out:
#                          Id            ParentId  Incoming  \
# 1136587  02s3x00001lwyxeAAA  5003x00002CFUfAAAX     False
# 1136585  02s3x00001lwzYbAAI  5003x00002CFUfAAAX     False
#
#                           MessageDate  \
# 1136587  2021-10-25T17:07:44.000+0000
# 1136585  2021-10-25T17:08:22.000+0000
#
#                                                   TextBody  \
# 1136587  fopittsburgh pa pam schon emailpambloomfieldga...
# 1136585  hi pam, i hope this email finds you well. we a...
#
#                        CreatedDate                    ClosedDate  \
# 1136587  2021-10-22 17:18:20+00:00  2021-10-25T17:08:45.000+0000
# 1136585  2021-10-22 17:18:20+00:00  2021-10-25T17:08:45.000+0000
#
#                                 Subtype  year  month       account_id  \
# 1136587  Charge or Credit Clarification  2021     10  0013x00002Ipz9G
# 1136585  Charge or Credit Clarification  2021     10  0013x00002Ipz9G
#
#             unum_id
# 1136587  1000110382
# 1136585  1000110382

# %%
df=pd.read_csv(os.path.join(my_folder, "unique_unum_v1.csv"), usecols=["unum_id"]).values
df.squeeze().shape
# Out:
# (8927,)

# %%
churn_data=pd.read_pickle(os.path.join(my_folder,'churn_data_pickle'))

# %%
churn_df=churn_data.copy()
text_df=askunum_text.copy()
churn_df["unum_id"]=churn_df["unum_id"].apply(str)
text_df["unum_id"]=askunum_text["unum_id"].astype(int).apply(str)

file_name="unique_unum_v1"
unique_unum_id=pd.read_csv(os.path.join(my_folder,file_name+".csv"))['unum_id'].values[0:10]
unique_unum_id=unique_unum_id.astype(str)
unique_unum_id
# Out:
# array(['1000110382', '1000197507', '1000210715', '1000233839',
#        '1000293377', '1000354872', '1000364014', '1000433738',
#        '1000437341', '1000469823'], dtype='<U21')

# %%
tempt=pd.DataFrame(unique_unum_id,columns=["unum_id"]).reset_index(drop=True)
tempt.to_csv(os.path.join(my_folder,"test.csv"))

# %%
pd.to_datetime(text_df["MessageDate"]).dt.date>=row["start_date"]
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
# 1136587    True
# 1136585    True
# 1136586    True
# 1136590    True
# 1136589    True
#            ...
# 892536     True
# 892539     True
# 892540     True
# 455631     True
# 455632     True
# Name: MessageDate, Length: 479, dtype: bool

# %%
row["start_date"]
# Out:
# Timestamp('2021-06-01 00:00:00')

# %%
row
# Out:
# unum_id                1000469823
# policy_id                  436049
# pivot_date    2022-03-01 00:00:00
# year                         2022
# month                           3
# start_date    2021-06-01 00:00:00
# end_date      2021-12-01 00:00:00
# churn                           0
# Name: 445511, dtype: object

# %%
text_df=text_df[text_df['unum_id'].isin(unique_unum_id)]
churn_df=churn_df[churn_df["unum_id"].isin(unique_unum_id)]

unum_id=[]
policy_id=[]
pivot_date=[]
year=[]
month=[]
start_date=[]
end_date=[]
Full_TextBody=[]
Client_TextBody=[]
Latest_TextBody=[]
Subtype=[]
churn=[]

# text_df.loc[:,'day']=1
# text_df.loc[:,'date']=pd.to_datetime(text_df[['year','month','day']],format="%Y%m%d")
# text_df.drop(['day'],inplace=True, axis=1)

for index,row in tqdm(churn_df.iterrows(), total=churn_df.shape[0]):

    ### Concatenate email message between start_date and end_date
    tempt=text_df[(text_df["unum_id"]==row["unum_id"]) & (pd.to_datetime(text_df["MessageDate"]).dt.date>=row["start_date"]) &  (pd.to_datetime(text_df["MessageDate"]).dt.date<=row["end_date"])]
    tempt.dropna(subset=["TextBody"],inplace=True)

    if tempt.empty:
        continue

    tempt.sort_values(["unum_id","MessageDate"],inplace=True,ascending=True)
    tempt2=tempt.drop_duplicates(subset=["unum_id"],keep="last")
    Subtype.append(tempt.drop_duplicates(subset=["unum_id"],keep="last")["Subtype"].values[0])
    
    tempt_1=tempt.groupby(["unum_id"])["TextBody"].apply(lambda x : ".".join(x)).reset_index()
    Full_TextBody.append(tempt_1["TextBody"][0])
    

    tempt_2=tempt[tempt["Incoming"]==True]
    tempt_2=tempt_2.groupby(["unum_id"])["TextBody"].apply(lambda x : ".".join(x)).reset_index()
    if tempt_2.empty:
        Client_TextBody.append(None)
    else:
        Client_TextBody.append(tempt_2["TextBody"][0])

    tempt_3=tempt.sort_values(["unum_id","ParentId","MessageDate"],ascending=True)
    tempt_3.drop_duplicates(subset=["unum_id","ParentId"],keep="last",inplace=True)
    tempt_3=tempt_3.groupby(["unum_id"])["TextBody"].apply(lambda x : ".".join(x)).reset_index()
    if tempt_3.empty:
        Latest_TextBody.append(None)
    else:
        Latest_TextBody.append(tempt_3["TextBody"][0])        

    unum_id.append(row["unum_id"])
    policy_id.append(row["policy_id"])
    pivot_date.append(row["pivot_date"])
    year.append(row["year"])
    month.append(row["month"])
    start_date.append(row["start_date"])
    end_date.append(row["end_date"])
    churn.append(row["churn"])
churn_text_data=pd.DataFrame({"unum_id":unum_id,"policy_id":policy_id,"pivot_date":pivot_date,"year":year,"month":month,\
                             "start_date":start_date,"end_date":end_date,"Full_TextBody":Full_TextBody,"Client_TextBody":Client_TextBody,\
                              "Latest_TextBody":Latest_TextBody,"Subtype":Subtype,"churn":churn})
# Out:
#   0%|          | 0/46 [00:00<?, ?it/s]/home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pandas/core/ops/array_ops.py:73: FutureWarning: Comparison of Timestamp with datetime.date is deprecated in order to match the standard library behavior.  In a future version these will be considered non-comparable.Use 'ts == pd.Timestamp(date)' or 'ts.date() == date' instead.
#   result = libops.scalar_compare(x.ravel(), y, op)
# /home/ec2-user/anaconda3/envs/amazonei_pytorch_latest_p37/lib/python3.7/site-packages/pandas/util/_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
# 100%|██████████| 46/46 [00:00<00:00, 136.58it/s]

# %%
churn_text_data
# Out:
#        unum_id  policy_id pivot_date  year  month start_date   end_date  \
# 0   1000469823     436049 2022-03-01  2022      3 2021-06-01 2021-12-01
# 1   1000437341     712269 2022-02-01  2022      2 2021-05-01 2021-11-01
# 2   1000437341     435828 2022-02-01  2022      2 2021-05-01 2021-11-01
# 3   1000433738     435500 2022-02-01  2022      2 2021-05-01 2021-11-01
# 4   1000364014     440697 2022-03-01  2022      3 2021-06-01 2021-12-01
# 5   1000364014     440697 2021-03-01  2021      3 2020-06-01 2020-12-01
# 6   1000364014     427531 2020-09-01  2020      9 2019-12-01 2020-06-01
# 7   1000354872     907863 2022-01-01  2022      1 2021-04-01 2021-10-01
# 8   1000354872     907863 2021-01-01  2021      1 2020-04-01 2020-10-01
# 9   1000354872     907863 2019-01-01  2019      1 2018-04-01 2018-10-01
# 10  1000354872     661715 2022-01-01  2022      1 2021-04-01 2021-10-01
# 11  1000354872     661715 2021-01-01  2021      1 2020-04-01 2020-10-01
# 12  1000354872     129840 2022-02-01  2022      2 2021-05-01 2021-11-01
# 13  1000354872     129840 2021-02-01  2021      2 2020-05-01 2020-11-01
# 14  1000354872     129840 2019-02-01  2019      2 2018-05-01 2018-11-01
# 15  1000233839     215066 2022-01-01  2022      1 2021-04-01 2021-10-01
# 16  1000233839     215066 2020-01-01  2020      1 2019-04-01 2019-10-01
# 17  1000210715     956327 2022-03-01  2022      3 2021-06-01 2021-12-01
# 18  1000210715     956327 2021-03-01  2021      3 2020-06-01 2020-12-01
# 19  1000210715     956326 2022-03-01  2022      3 2021-06-01 2021-12-01
# 20  1000210715     956326 2021-03-01  2021      3 2020-06-01 2020-12-01
# 21  1000210715     436191 2022-03-01  2022      3 2021-06-01 2021-12-01
# 22  1000210715     436191 2021-03-01  2021      3 2020-06-01 2020-12-01
# 23  1000110382     436760 2022-03-01  2022      3 2021-06-01 2021-12-01
#
#                                         Full_TextBody  \
# 0   hello, can you please assist me in obtaining t...
# 1   policy holder bridgewater homes policy number ...
# 2   policy holder bridgewater homes policy number ...
# 3   unum covid response click herehttpsbit.lycjrbm...
# 4   lucy, happy to assist hope you have been doing...
# 5   , , arthritis osteoporosis center of south tex...
# 6   to whom it may concern, my name is nikki marti...
# 7   good afternoon, we see george hurt was reinsta...
# 8   hi askunum, i am hoping someone might be able ...
# 9   this message originated outside of unum. use c...
# 10  good afternoon, we see george hurt was reinsta...
# 11  hi askunum, i am hoping someone might be able ...
# 12  good afternoon, we see george hurt was reinsta...
# 13  kim davis, can you please process the below eo...
# 14  this message originated outside of unum. use c...
# 15  gscmi stephanie johnson client name mcguffey s...
# 16  hello lynn, thank you for your call attached i...
# 17  gscmi lisa keane client name tribeca pediatric...
# 18  thank you anna for an employee non manager or ...
# 19  gscmi lisa keane client name tribeca pediatric...
# 20  thank you anna for an employee non manager or ...
# 21  gscmi lisa keane client name tribeca pediatric...
# 22  thank you anna for an employee non manager or ...
# 23  fopittsburgh pa pam schon emailpambloomfieldga...
#
#                                       Client_TextBody  \
# 0   hello, can you please assist me in obtaining t...
# 1   policy holder bridgewater homes policy number ...
# 2   policy holder bridgewater homes policy number ...
# 3   unum covid response click herehttpsbit.lycjrbm...
# 4   lucy, happy to assist hope you have been doing...
# 5                                                None
# 6   to whom it may concern, my name is nikki marti...
# 7   good afternoon, we see george hurt was reinsta...
# 8   hi askunum, i am hoping someone might be able ...
# 9   this message originated outside of unum. use c...
# 10  good afternoon, we see george hurt was reinsta...
# 11  hi askunum, i am hoping someone might be able ...
# 12  good afternoon, we see george hurt was reinsta...
# 13  kim davis, can you please process the below eo...
# 14  this message originated outside of unum. use c...
# 15  gscmi stephanie johnson client name mcguffey s...
# 16  please see the attached form. thank you, lynn ...
# 17  gscmi lisa keane client name tribeca pediatric...
# 18  thank you anna for an employee non manager or ...
# 19  gscmi lisa keane client name tribeca pediatric...
# 20  thank you anna for an employee non manager or ...
# 21  gscmi lisa keane client name tribeca pediatric...
# 22  thank you anna for an employee non manager or ...
# 23  we still have not been contacted by anyone. th...
#
#                                       Latest_TextBody  \
# 0   broker id hello tessa, thank you for your emai...
# 1   good afternoon, congratulations on being named...
# 2   good afternoon, congratulations on being named...
# 3   hello, can you please reset my unum password. ...
# 4   great, thank you thank you, lucy .. lucero rod...
# 5   , , arthritis osteoporosis center of south tex...
# 6   , good afternoon nikki, thank you for your ema...
# 7   good afternoon, we see george hurt was reinsta...
# 8   hello ginnifer, thank you for reaching out. we...
# 9   hello shakila, thank you for your email. pleas...
# 10  good afternoon, we see george hurt was reinsta...
# 11  hello ginnifer, thank you for reaching out. we...
# 12  good afternoon, we see george hurt was reinsta...
# 13  hello, i have sent the eob to starmounts claim...
# 14  hello shakila, thank you for your email. pleas...
# 15  mcguffey school district hello lynn, we want t...
# 16  please see the attached form. thank you, lynn ...
# 17  tribeca pediatrics hello shari, we received an...
# 18  dear unum, please advise on the status of the ...
# 19  tribeca pediatrics hello shari, we received an...
# 20  dear unum, please advise on the status of the ...
# 21  tribeca pediatrics hello shari, we received an...
# 22  dear unum, please advise on the status of the ...
# 23  we still have not been contacted by anyone. th...
#
#                                Subtype  churn
# 0                      Employee Coding      0
# 1                           BOR Packet      0
# 2                           BOR Packet      0
# 3        Premium Calculation Education      0
# 4                      Employee Coding      0
# 5      Online Payment Inquiry or Setup      0
# 6   Add, Remove, or Update user access      1
# 7                      Employee Coding      0
# 8                 Compensation Inquiry      0
# 9                Enrollment Submission      0
# 10                     Employee Coding      0
# 11                Compensation Inquiry      0
# 12                     Employee Coding      0
# 13                            Contract      0
# 14               Enrollment Submission      0
# 15                 Missing Information      0
# 16                   Enrollment Status      0
# 17                             Invoice      0
# 18              Benefit Payment Status      0
# 19                             Invoice      0
# 20              Benefit Payment Status      0
# 21                             Invoice      0
# 22              Benefit Payment Status      0
# 23      Charge or Credit Clarification      0

# %%
tempt2=tempt.drop_duplicates(subset=["unum_id"],keep="last")
tempt2["Subtype"].values[0]
# Out:
# 'Employee Coding'

# %%
churn_text_data=pd.DataFrame({"unum_id":unum_id,"policy_id":policy_id,"pivot_date":pivot_date,"year":year,"month":month,
                             "start_date":start_date,"end_date":end_date,"Full_TextBody":Full_TextBody,"Client_TextBody":Client_TextBody,"Latest_TextBody":Latest_TextBody,"churn":churn})

# %%
churn_text_data
# Out:
#        unum_id  policy_id pivot_date  year  month start_date   end_date  \
# 0   1000469823     436049 2022-03-01  2022      3 2021-06-01 2021-12-01
# 1   1000437341     712269 2022-02-01  2022      2 2021-05-01 2021-11-01
# 2   1000437341     435828 2022-02-01  2022      2 2021-05-01 2021-11-01
# 3   1000433738     435500 2022-02-01  2022      2 2021-05-01 2021-11-01
# 4   1000364014     440697 2022-03-01  2022      3 2021-06-01 2021-12-01
# 5   1000364014     440697 2021-03-01  2021      3 2020-06-01 2020-12-01
# 6   1000364014     427531 2020-09-01  2020      9 2019-12-01 2020-06-01
# 7   1000354872     907863 2022-01-01  2022      1 2021-04-01 2021-10-01
# 8   1000354872     907863 2021-01-01  2021      1 2020-04-01 2020-10-01
# 9   1000354872     907863 2019-01-01  2019      1 2018-04-01 2018-10-01
# 10  1000354872     661715 2022-01-01  2022      1 2021-04-01 2021-10-01
# 11  1000354872     661715 2021-01-01  2021      1 2020-04-01 2020-10-01
# 12  1000354872     129840 2022-02-01  2022      2 2021-05-01 2021-11-01
# 13  1000354872     129840 2021-02-01  2021      2 2020-05-01 2020-11-01
# 14  1000354872     129840 2019-02-01  2019      2 2018-05-01 2018-11-01
# 15  1000233839     215066 2022-01-01  2022      1 2021-04-01 2021-10-01
# 16  1000233839     215066 2020-01-01  2020      1 2019-04-01 2019-10-01
# 17  1000210715     956327 2022-03-01  2022      3 2021-06-01 2021-12-01
# 18  1000210715     956327 2021-03-01  2021      3 2020-06-01 2020-12-01
# 19  1000210715     956326 2022-03-01  2022      3 2021-06-01 2021-12-01
# 20  1000210715     956326 2021-03-01  2021      3 2020-06-01 2020-12-01
# 21  1000210715     436191 2022-03-01  2022      3 2021-06-01 2021-12-01
# 22  1000210715     436191 2021-03-01  2021      3 2020-06-01 2020-12-01
# 23  1000110382     436760 2022-03-01  2022      3 2021-06-01 2021-12-01
#
#                                         Full_TextBody  \
# 0   hello, can you please assist me in obtaining t...
# 1   policy holder bridgewater homes policy number ...
# 2   policy holder bridgewater homes policy number ...
# 3   unum covid response click herehttpsbit.lycjrbm...
# 4   lucy, happy to assist hope you have been doing...
# 5   , , arthritis osteoporosis center of south tex...
# 6   to whom it may concern, my name is nikki marti...
# 7   good afternoon, we see george hurt was reinsta...
# 8   hi askunum, i am hoping someone might be able ...
# 9   this message originated outside of unum. use c...
# 10  good afternoon, we see george hurt was reinsta...
# 11  hi askunum, i am hoping someone might be able ...
# 12  good afternoon, we see george hurt was reinsta...
# 13  kim davis, can you please process the below eo...
# 14  this message originated outside of unum. use c...
# 15  gscmi stephanie johnson client name mcguffey s...
# 16  hello lynn, thank you for your call attached i...
# 17  gscmi lisa keane client name tribeca pediatric...
# 18  thank you anna for an employee non manager or ...
# 19  gscmi lisa keane client name tribeca pediatric...
# 20  thank you anna for an employee non manager or ...
# 21  gscmi lisa keane client name tribeca pediatric...
# 22  thank you anna for an employee non manager or ...
# 23  fopittsburgh pa pam schon emailpambloomfieldga...
#
#                                       Client_TextBody  \
# 0   hello, can you please assist me in obtaining t...
# 1   policy holder bridgewater homes policy number ...
# 2   policy holder bridgewater homes policy number ...
# 3   unum covid response click herehttpsbit.lycjrbm...
# 4   lucy, happy to assist hope you have been doing...
# 5                                                None
# 6   to whom it may concern, my name is nikki marti...
# 7   good afternoon, we see george hurt was reinsta...
# 8   hi askunum, i am hoping someone might be able ...
# 9   this message originated outside of unum. use c...
# 10  good afternoon, we see george hurt was reinsta...
# 11  hi askunum, i am hoping someone might be able ...
# 12  good afternoon, we see george hurt was reinsta...
# 13  kim davis, can you please process the below eo...
# 14  this message originated outside of unum. use c...
# 15  gscmi stephanie johnson client name mcguffey s...
# 16  please see the attached form. thank you, lynn ...
# 17  gscmi lisa keane client name tribeca pediatric...
# 18  thank you anna for an employee non manager or ...
# 19  gscmi lisa keane client name tribeca pediatric...
# 20  thank you anna for an employee non manager or ...
# 21  gscmi lisa keane client name tribeca pediatric...
# 22  thank you anna for an employee non manager or ...
# 23  we still have not been contacted by anyone. th...
#
#                                       Latest_TextBody  churn
# 0   broker id hello tessa, thank you for your emai...      0
# 1   good afternoon, congratulations on being named...      0
# 2   good afternoon, congratulations on being named...      0
# 3   hello, can you please reset my unum password. ...      0
# 4   great, thank you thank you, lucy .. lucero rod...      0
# 5   , , arthritis osteoporosis center of south tex...      0
# 6   , good afternoon nikki, thank you for your ema...      1
# 7   good afternoon, we see george hurt was reinsta...      0
# 8   hello ginnifer, thank you for reaching out. we...      0
# 9   hello shakila, thank you for your email. pleas...      0
# 10  good afternoon, we see george hurt was reinsta...      0
# 11  hello ginnifer, thank you for reaching out. we...      0
# 12  good afternoon, we see george hurt was reinsta...      0
# 13  hello, i have sent the eob to starmounts claim...      0
# 14  hello shakila, thank you for your email. pleas...      0
# 15  mcguffey school district hello lynn, we want t...      0
# 16  please see the attached form. thank you, lynn ...      0
# 17  tribeca pediatrics hello shari, we received an...      0
# 18  dear unum, please advise on the status of the ...      0
# 19  tribeca pediatrics hello shari, we received an...      0
# 20  dear unum, please advise on the status of the ...      0
# 21  tribeca pediatrics hello shari, we received an...      0
# 22  dear unum, please advise on the status of the ...      0
# 23  we still have not been contacted by anyone. th...      0
